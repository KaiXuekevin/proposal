# %%
import pandas as pd
cols = pd.read_csv("var_names.csv")
data = pd.read_csv("CSCS_data_anon.csv",
                   na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only

# Let's just keep the recommended data
dataV2 = data[data.REMOVE_case=='No'].copy()

dataV2_cohort = dataV2[dataV2.SURVEY_cohort_participant].copy()
dataV2_cohortV2 = dataV2_cohort[dataV2_cohort.SURVEY_collection_year!=2023].copy()
missingness_limit = 100 # this retains 166 of 1024 columns that aren't fully empty
columns2keep = dataV2_cohortV2.isna().sum() < missingness_limit
columns2keep = columns2keep.index[columns2keep]
dataV2_cohortV3 = dataV2_cohortV2[columns2keep].copy()
dataV2_cohortV3.shape

# The data itself then looks like this
pd.set_option('display.max_columns', dataV2_cohortV3.shape[1]) # Can cause jupyter notebooks to crash
# DO NOT USE in conjuection with pd.set_option('display.max_rows', 1000) 
dataV2_cohortV3
# Out:
# /tmp/ipykernel_87/1610598462.py:3: DtypeWarning: Columns (129,408,630,671,689,978,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1263,1266,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1439,1442,1463,1546,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("CSCS_data_anon.csv",
#         UNIQUE_id  UNIQUE_num_records ELIGIBLE_consent  \
# 19     cscs_00021                   3              Yes
# 21     cscs_00021                   3              Yes
# 71     cscs_00074                   3              Yes
# 77     cscs_00080                   2              Yes
# 78     cscs_00080                   2              Yes
# ...           ...                 ...              ...
# 11379  cscs_11760                   3              Yes
# 11380  cscs_11760                   3              Yes
# ...

# %% [markdown]
# Background:
# The COVID-19 outbreak has been a popular research topic among researchers in various fields. Physical and mental health issues of both society and individuals have been studied extensively. I have found that some of the behaviour in the outbreak seem to have a strong relationship with people's mental health.
#
# I therefore propose three questions that need to be examined and hope to verify my conjectures with some data. Regarding the selection of the variables under study, I will purposely select three sets of variables, one set of two categorical variables, one set of one categorical variable and one numerical variable, and one set of two numerical variables. Try to explore the relationship between them in different ways.

# %% [markdown]
# Analysis 1
#
# research question: Explore the relationship between whether participants took social distance measures during COVID-19 and participants' feelings of helplessness. Are the two related? Do people feel helpless because they socialise less in COVID-19?
#
# variables: COVID_prevention_distancing(categorical): This variable indicates the extent to which participants took social distance during the study period
#
# WELLNESS_malach_pines_burnout_measure_helpless(categorical)：This variable indicates the frequency with which participants felt helplessness
#
# visualisation method：Stacked Bar Chart: A stacked bar chart can show the distribution of two categorical variables. For example, the proportions of people who are ‘Very closely’ in distancing,‘somewhat closely' and 'Not at all' in distancing can be coloured differently and then stacked on the same chart by level of helplessness. ‘This method helps to visually compare the different groups. This approach helps to visualise the differences between the different groups.
#
# analysis: We can basically determine the relationship between two variables by looking at the distribution of different colours in the bar chart. At the same time we can make an assumption about the relationship between the two variables to calculate the p-value. If the p-value is less than the level of significance (e.g. 0.05), the assumption of independence can be rejected and the two variables are considered to be related.
#
# hypothesis: The height of the colour bar representing no reduction in socialisation was greatest in the bar for those who did not feel much helplessness. The height of the colour bar for completely reduced socialisation is greatest among those who feel helpless a lot. The p-value is less than the level of significance (e.g. 0.05). So I think the two variables are related.

# %% [markdown]
# Analysis 2
#
# Research question: Explore the relationship between people's happiness index and the frequency of sickness.
#
# variables: WELLNESS_malach_pines_burnout_measure_sick(categorical)：This variable represents how often participants were sick during the study period
#
# WELLNESS_subjective_happiness_scale_happy(numerical)：This variable represents an index of how happy the researcher perceived herself to be during the study period.Do people often get sick during outbreaks? Are people unhappy because they are sick in the epidemic?
#
# visualisation method: Box plots are good for showing the distribution of numerical variables across different categories. For example, I could plot the distribution of the happiness score under the category ‘Never’ sick. Box plots can show medians, quartiles and potential outliers.
# In order to study how sick people are it is also possible to use pie charts to determine the proportion of researchers who are in different sick situations.
#
# analysis we plan on performing: At the same time, we can use bootstrapping to estimate confidence intervals for the difference in the means of the happiness scores for the different ‘feeling sick’ categories. If the confidence interval includes zero, the difference in well-being between the two groups may not be significant; if it does not include zero, there may be a significant difference.
#
# hypothesis: I think that in the pie chart, sick researchers should be in the majority and never sick researchers should be in the minority. The people who are sick more often in the box plot should have lower happy stats for each, and correspondingly the people who are sick less often will have higher happy stats, but there is bound to be outlier among them. And through bootstrapping, we can get that people's happiness is related to the frequency of illness.

# %% [markdown]
# Analysis 3
#
# Reasearch question: Explore the relationship between the happiness index given by participants and the always happiness index. What is their linear relationship like?
#
# variables: WELLNESS_subjective_happiness_scale_happy(numerical)：This variable represents an index of how happy the researcher perceived herself to be during the study period.
#
# WELLNESS_subjective_happiness_scale_always_happy(numerical)：This variable represents an index of the researcher's perception that he or she was always happy during the study period.
#
# visualisation method: We can use scatter plots and regression lines as linear regression visualisation methods for showing the distribution of data points and how well the model fits. Scatterplots show the actual observations of the data, while regression lines show the predictions of the model.
#
# analysis we plan on performing: Because both variables are NUMERICAL variables. So I think exploring their linear regression relationship. Determine the relationship between the two variables by calculating linear regression coefficients and so on.
# $$\Large Y_i = \beta_0 + \beta_1 x_i + \epsilon_i \quad \text{ where } \quad \epsilon_i \sim \mathcal N\left(0, \sigma\right)$$
# We can also investigate this by fitting the simple linear regression model we have learnt. Finding the parameters β0 and β1 of the best-fit line using linear regression is usually achieved by least squares, i.e. minimising the sum of the squares of the perpendicular distances from all points to the fitted line.
#
# hypothesis: In general, the happy index and the always happy index are positively correlated. However, in the context we are studying, I believe that a linear relationship between these two variables may exist, but it will not be strong and is not a perfect positive correlation. This is because I think that some people who are happy in Covid-19 have a hard time being happy all the time.

# %% [markdown]
# Conclusion: After combining the results obtained through statistical methods with my hypothesis, I can get some conclusions that people related in Covid-19. I can even simulate the whole human race while using it as a sample. This can be of great help for subsequent research, such as helping psychologists to better heal their patients.
